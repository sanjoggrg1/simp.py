# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjoggrg1/simp.py/blob/main/EDA_(Toy_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/toy_dataset.csv")

# %%
data.head(7)
# Out:
#    Number    City  Gender  Age   Income Illness
# 0       1  Dallas    Male   41  40367.0      No
# 1       2  Dallas    Male   54  45084.0      No
# 2       3  Dallas    Male   42  52483.0      No
# 3       4  Dallas    Male   40  40941.0      No
# 4       5  Dallas    Male   46  50289.0      No
# 5       6  Dallas  Female   36  50786.0      No
# 6       7  Dallas  Female   32  33155.0      No

# %%
data.shape
# Out:
# (150000, 6)

# %%
data.isnull().sum()
# Out:
# Number     0
# City       0
# Gender     0
# Age        0
# Income     0
# Illness    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Number   150000 non-null  int64
#  1   City     150000 non-null  object
#  2   Gender   150000 non-null  object
#  3   Age      150000 non-null  int64
#  4   Income   150000 non-null  float64
#  5   Illness  150000 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 6.9+ MB

# %%
data.describe()
# Out:
#               Number            Age         Income
# count  150000.000000  150000.000000  150000.000000
# mean    75000.500000      44.950200   91252.798273
# std     43301.414527      11.572486   24989.500948
# min         1.000000      25.000000    -654.000000
# 25%     37500.750000      35.000000   80867.750000
# 50%     75000.500000      45.000000   93655.000000
# 75%    112500.250000      55.000000  104519.000000
# max    150000.000000      65.000000  177157.000000

# %%
data['City'].value_counts()
# Out:
# City
# New York City      50307
# Los Angeles        32173
# Dallas             19707
# Mountain View      14219
# Austin             12292
# Boston              8301
# Washington D.C.     8120
# San Diego           4881
# Name: count, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      83800
# Female    66200
# Name: count, dtype: int64

# %%
data['Illness'].value_counts()
# Out:
# Illness
# No     137861
# Yes     12139
# Name: count, dtype: int64

# %%
df = pd.DataFrame(data)
df.head(4)
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No

# %%
df.columns
# Out:
# Index(['Number', 'City', 'Gender', 'Age', 'Income', 'Illness'], dtype='object')

# %%
auto = df[['Number', 'City', 'Gender', 'Age', 'Income', 'Illness']]

# %%
plt.figure(figsize=(10,5))
sb.barplot(x = df['City'].value_counts().values, y = df['City'].value_counts().index,palette='Set2')
plt.title('City wise distribution')
plt.xlabel('Counts')
plt.ylabel('Cities')
plt.show()

# %%
plt.figure(figsize=(10,5))
values = data['Gender'].value_counts().values
counts = data['Gender'].value_counts().index
colors = ['Red','Blue']
plt.pie(values,labels = counts,colors = colors,autopct='%1.1f')
plt.title('Comparision of Gender')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
values = data['Illness'].value_counts().values
counts = data['Illness'].value_counts().index
colors = ['Yellow','Pink']
explode = [0,0.1]
plt.pie(values,labels = counts,colors = colors,explode = explode,autopct='%1.1f')
plt.title('Illness Distribution')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
sb.barplot(x = df['Illness'].value_counts().index, y = df['Illness'].value_counts().values)
plt.title('Ilness')
plt.xlabel('Counts')
plt.ylabel('Type')
plt.show()

# %%
plt.figure(figsize=(10,5))
sb.scatterplot(x = 'Age', y = 'Illness', data = auto)
plt.title('Age vs Illness')
plt.xlabel('Age')
plt.ylabel('Illness')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,5))
sb.histplot(df['Income'], bins = 30,kde = True, color= 'Purple')
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
auto2=df[["Age", "Income", "Number"]]
auto2.corr()
# Out:
#              Age    Income    Number
# Age     1.000000 -0.001318 -0.003448
# Income -0.001318  1.000000  0.410460
# Number -0.003448  0.410460  1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(auto2.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sb.countplot(x = 'City',hue = 'Gender',data = auto, palette= 'Set3')
plt.title('Gender Distribution by city')
plt.show()
